# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Bristol_Mobility_Report_2020-2022.xlsx')
df = df.drop(columns=['country_region_code', 'sub_region_2', 'metro_area', 'iso_3166_2_code', 'census_fips_code', 'place_id',
            'Unnamed: 15'], axis=1)
df.head(10)
# Out:
#    country_region  sub_region_1       date  retail_and_recreation  \
# 0  United Kingdom  Bristol City 2020-02-15                    -17
# 1  United Kingdom  Bristol City 2020-02-16                     -7
# 2  United Kingdom  Bristol City 2020-02-17                      5
# 3  United Kingdom  Bristol City 2020-02-18                     11
# 4  United Kingdom  Bristol City 2020-02-19                      5
# 5  United Kingdom  Bristol City 2020-02-20                      7
# 6  United Kingdom  Bristol City 2020-02-21                      7
# 7  United Kingdom  Bristol City 2020-02-22                     -3
# 8  United Kingdom  Bristol City 2020-02-23                      3
# 9  United Kingdom  Bristol City 2020-02-24                     -7
#
#    grocery_and_pharmacy  parks  transit_stations  workplaces  residential
# 0                   -10    -48                -9          -4            3
# 1                    -5    -34                -1          -1            1
# ...

# %%
df.plot.line(x="date")
plt.show()

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:xlabel='date'>
