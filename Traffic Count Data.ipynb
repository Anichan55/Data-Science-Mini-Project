# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\ishwa\OneDrive\Desktop\dft_rawcount_local_authority_id_144.csv')

# %%
df
# Out:
#        count_point_id direction_of_travel  year  count_date  hour  region_id  \
# 0              966008                   E  2003  26/09/2003     7          1
# 1              966008                   E  2003  26/09/2003     8          1
# 2              966008                   E  2003  26/09/2003     9          1
# 3              966008                   E  2003  26/09/2003    10          1
# 4              966008                   E  2003  26/09/2003    11          1
# ...               ...                 ...   ...         ...   ...        ...
# 26863          966011                   E  2003  20/03/2003     8          1
# 26864          966011                   E  2003  20/03/2003     9          1
# 26865          966011                   E  2003  20/03/2003    10          1
# 26866          966011                   E  2003  20/03/2003    11          1
# 26867          966011                   E  2003  20/03/2003    12          1
#
# ...

# %%
df = df.sort_values(by='year')

# %%
df
# Out:
#        count_point_id direction_of_travel  year  count_date  hour  region_id  \
# 3743           990068                   E  2000  26/06/2000    18          1
# 2925            73295                   S  2000  11/10/2000     8          1
# 2924            73295                   S  2000  11/10/2000     7          1
# 2923            73295                   N  2000  11/10/2000    18          1
# 2922            73295                   N  2000  11/10/2000    17          1
# ...               ...                 ...   ...         ...   ...        ...
# 12237           99507                   S  2020  11/06/2020     7          1
# 12236           99507                   S  2020  11/06/2020    18          1
# 12235           99507                   S  2020  11/06/2020    17          1
# 12233           99507                   S  2020  11/06/2020    15          1
# 12339           81538                   N  2020  17/07/2020    13          1
#
# ...

# %%
df.isnull().sum()
# Out:
# count_point_id                      0
# direction_of_travel                 0
# year                                0
# count_date                          0
# hour                                0
# region_id                           0
# region_name                         0
# local_authority_id                  0
# local_authority_name                0
# road_name                           0
# road_type                           0
# start_junction_road_name        16608
# end_junction_road_name          16608
# easting                             0
# northing                            0
# latitude                            0
# longitude                           0
# link_length_km                  16608
# link_length_miles               16608
# pedal_cycles                        0
# two_wheeled_motor_vehicles          0
# cars_and_taxis                      0
# buses_and_coaches                   0
# lgvs                                0
# hgvs_2_rigid_axle                   0
# ...

# %%
#Dropping unwanted columns
cols = [11,12,17,18]
df.drop(df.columns[cols],axis=1,inplace=True)

# %%
df
# Out:
#        count_point_id direction_of_travel  year  count_date  hour  region_id  \
# 3743           990068                   E  2000  26/06/2000    18          1
# 2925            73295                   S  2000  11/10/2000     8          1
# 2924            73295                   S  2000  11/10/2000     7          1
# 2923            73295                   N  2000  11/10/2000    18          1
# 2922            73295                   N  2000  11/10/2000    17          1
# ...               ...                 ...   ...         ...   ...        ...
# 12237           99507                   S  2020  11/06/2020     7          1
# 12236           99507                   S  2020  11/06/2020    18          1
# 12235           99507                   S  2020  11/06/2020    17          1
# 12233           99507                   S  2020  11/06/2020    15          1
# 12339           81538                   N  2020  17/07/2020    13          1
#
# ...

# %%
df.isnull().sum()
# Out:
# count_point_id                  0
# direction_of_travel             0
# year                            0
# count_date                      0
# hour                            0
# region_id                       0
# region_name                     0
# local_authority_id              0
# local_authority_name            0
# road_name                       0
# road_type                       0
# easting                         0
# northing                        0
# latitude                        0
# longitude                       0
# pedal_cycles                    0
# two_wheeled_motor_vehicles      0
# cars_and_taxis                  0
# buses_and_coaches               0
# lgvs                            0
# hgvs_2_rigid_axle               0
# hgvs_3_rigid_axle               0
# hgvs_4_or_more_rigid_axle       0
# hgvs_3_or_4_articulated_axle    0
# hgvs_5_articulated_axle         0
# hgvs_6_articulated_axle         0
# all_hgvs                        0
# ...

# %%
df.to_csv('dft_rawcount_local_authority_id_144.csv')
