# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Final data.csv")
df
# Out:
#            Date   CPI  Median Annual Income  Population Estimate  \
# 0    31-10-2011  94.5           26719.28962          430572.0765
# 1    30-11-2011  94.6           26652.97814          430979.3716
# 2    31-12-2011  95.1           26584.45628          431400.2432
# 3    31-01-2012  94.6           26515.93443          431821.1148
# 4    29-02-2012  95.1           26451.83333          432214.8333
# ..          ...   ...                   ...                  ...
# 178  31-08-2026   NaN                   NaN                  NaN
# 179  30-09-2026   NaN                   NaN                  NaN
# 180  31-10-2026   NaN                   NaN                  NaN
# 181  30-11-2026   NaN                   NaN                  NaN
# 182  31-12-2026   NaN                   NaN                  NaN
#
#      Petrol Price  Diesel Price  Google Search Index  All Cars  ULEV
# 0          1.3473        1.4027                 23.0  206427.0  31.0
# ...

# %%
df=df.dropna()

# %%
#separate the other attributes from the predicting attribute
x = df.drop(columns=['Date','All Cars', 'ULEV'])
#separte the predicting attribute into Y for model training 
y = df['All Cars']
Y = df['ULEV']

# %%
x
# Out:
#        CPI  Median Annual Income  Population Estimate  Petrol Price  \
# 0     94.5           26719.28962          430572.0765        1.3473
# 1     94.6           26652.97814          430979.3716        1.3317
# 2     95.1           26584.45628          431400.2432        1.3241
# 3     94.6           26515.93443          431821.1148        1.3410
# 4     95.1           26451.83333          432214.8333        1.3621
# ..     ...                   ...                  ...           ...
# 106  108.6           32819.57260          465877.4575        1.1329
# 107  109.1           32779.95616          465880.2521        1.1330
# 108  109.1           32739.01918          465883.1397        1.1314
# 109  108.9           32699.40274          465885.9342        1.1261
# 110  109.2           32658.46575          465888.8219        1.1491
#
#      Diesel Price  Google Search Index
# 0          1.4027                 23.0
# 1          1.4110                 22.0
# ...

# %%
y
# Out:
# 0      206427.0
# 1      207544.0
# 2      208700.0
# 3      209690.0
# 4      210618.0
#          ...
# 106    182533.0
# 107    182451.0
# 108    182366.0
# 109    182284.0
# 110    182200.0
# Name: All Cars, Length: 111, dtype: float64

# %%
Y
# Out:
# 0        31.0
# 1        31.0
# 2        31.0
# 3        31.0
# 4        33.0
#         ...
# 106    1719.0
# 107    1795.0
# 108    1874.0
# 109    1919.0
# 110    1966.0
# Name: ULEV, Length: 111, dtype: float64

# %%
# importing train_test_split from sklearn
from sklearn.model_selection import train_test_split
# splitting the data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, shuffle=False)

# %%
# importing module
from sklearn.linear_model import LinearRegression
# creating an object of LinearRegression class
LR = LinearRegression()
# fitting the training data
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_prediction =  LR.predict(x_test)
y_prediction
# Out:
# array([157929.9798265 , 150072.26544277, 156584.30118391, 132901.39156326,
#        148128.20297461, 145902.79399632, 139059.08789639, 145539.66757526,
#         86170.8515365 , 100490.60006163, 100383.79924081,  77625.35114207,
#         47811.93045377, 115845.19304049, 172833.6647467 , 152938.12551796,
#        120720.39887709, 107042.55507724, 122559.79389475,  93700.68703914,
#        108416.89432041,  83427.81981268, 116438.75022557])

# %%
# importing r2_score module
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
# predicting the accuracy score
score=r2_score(y_test,y_prediction)
print('r2 socre is ',score)
print('mean_sqrd_error is==',mean_squared_error(y_test,y_prediction))
print('root_mean_squared error of is==',np.sqrt(mean_squared_error(y_test,y_prediction)))
# Out:
# r2 socre is  -61591.529923054564
# mean_sqrd_error is== 4750644174.757583
# root_mean_squared error of is== 68924.91693689287

# %%
# create data frame
compare_y = df[int(110*0.8):]
compare_y = compare_y['Date']
compare_y = pd.DataFrame(compare_y)
compare_y.reset_index(drop=True, inplace=True)
y_test= pd.DataFrame(y_test)
y_test.reset_index(drop=True, inplace=True)
y_prediction = pd.DataFrame(y_prediction)
y_prediction.reset_index(drop=True, inplace=True)
compare_y = pd.merge(compare_y, y_test, left_index=True, right_index=True, how="inner")
compare_y = pd.merge(compare_y, y_prediction, left_index=True, right_index=True, how="inner")
compare_y.index = compare_y['Date']
del compare_y['Date']
compare_y.columns = ['Test_All Cars', 'Predict_All Cars']
compare_y
# Out:
#             Test_All Cars  Predict_All Cars
# Date
# 28-02-2019       182445.0     157929.979826
# 31-03-2019       182521.0     150072.265443
# 30-04-2019       182595.0     156584.301184
# 31-05-2019       182672.0     132901.391563
# 30-06-2019       182746.0     148128.202975
# 31-07-2019       182822.0     145902.793996
# 31-08-2019       182899.0     139059.087896
# 30-09-2019       182973.0     145539.667575
# 31-10-2019       183049.0      86170.851536
# 30-11-2019       183123.0     100490.600062
# 31-12-2019       183200.0     100383.799241
# 31-01-2020       183115.0      77625.351142
# 29-02-2020       183036.0      47811.930454
# 31-03-2020       182951.0     115845.193040
# 30-04-2020       182869.0     172833.664747
# 31-05-2020       182784.0     152938.125518
# 30-06-2020       182702.0     120720.398877
# 31-07-2020       182618.0     107042.555077
# 31-08-2020       182533.0     122559.793895
# 30-09-2020       182451.0      93700.687039
# ...

# %%
#plot
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize = (15,8))
plt.plot(compare_y['Test_All Cars'], label='Test_All Cars')
plt.plot(compare_y['Predict_All Cars'], label='Predict_All Cars')
plt.legend()

# %%
# splitting the data
x_train, x_test, Y_train, Y_test = train_test_split(x, Y, test_size = 0.2, shuffle=False)

# %%
# creating an object of LinearRegression class
LR2 = LinearRegression()
# fitting the training data
LR2.fit(x_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_prediction =  LR2.predict(x_test)
Y_prediction
# Out:
# array([614.46517295, 600.62578495, 565.26977608, 526.98252103,
#        473.1469435 , 474.9866939 , 422.79862946, 422.12316992,
#        369.80914173, 362.37310027, 377.88524721, 407.55466308,
#        277.47007952, 273.82766984, 318.59757957, 251.39192289,
#        192.28972741, 211.85782862, 275.58549856, 205.282041  ,
#        222.95677899, 210.11849554, 241.54030791])

# %%
# predicting the accuracy score
score=r2_score(Y_test,Y_prediction)
print('r2 socre is ',score)
print('mean_sqrd_error is==',mean_squared_error(Y_test,Y_prediction))
print('root_mean_squared error of is==',np.sqrt(mean_squared_error(Y_test,Y_prediction)))
# Out:
# r2 socre is  -8.620937323449164
# mean_sqrd_error is== 1180425.3549924449
# root_mean_squared error of is== 1086.473816984305

# %%
# create data frame
compare_Y = df[int(110*0.8):]
compare_Y = compare_Y['Date']
compare_Y = pd.DataFrame(compare_Y)
compare_Y.reset_index(drop=True, inplace=True)
Y_test= pd.DataFrame(Y_test)
Y_test.reset_index(drop=True, inplace=True)
Y_prediction = pd.DataFrame(Y_prediction)
Y_prediction.reset_index(drop=True, inplace=True)
compare_Y = pd.merge(compare_Y, Y_test, left_index=True, right_index=True, how="inner")
compare_Y = pd.merge(compare_Y, Y_prediction, left_index=True, right_index=True, how="inner")
compare_Y.index = compare_Y['Date']
del compare_Y['Date']
compare_Y.columns = ['Test_ULEV', 'Predict_ULEV']
compare_Y
# Out:
#             Test_ULEV  Predict_ULEV
# Date
# 28-02-2019      835.0    614.465173
# 31-03-2019      860.0    600.625785
# 30-04-2019      884.0    565.269776
# 31-05-2019      928.0    526.982521
# 30-06-2019      970.0    473.146944
# 31-07-2019     1015.0    474.986694
# 31-08-2019     1064.0    422.798629
# 30-09-2019     1113.0    422.123170
# 31-10-2019     1163.0    369.809142
# 30-11-2019     1217.0    362.373100
# 31-12-2019     1273.0    377.885247
# 31-01-2020     1330.0    407.554663
# 29-02-2020     1359.0    277.470080
# 31-03-2020     1390.0    273.827670
# 30-04-2020     1420.0    318.597580
# 31-05-2020     1494.0    251.391923
# 30-06-2020     1566.0    192.289727
# 31-07-2020     1641.0    211.857829
# 31-08-2020     1719.0    275.585499
# 30-09-2020     1795.0    205.282041
# 31-10-2020     1874.0    222.956779
# 30-11-2020     1919.0    210.118496
# 31-12-2020     1966.0    241.540308

# %%
#plot
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize = (15,8))
plt.plot(compare_Y['Test_ULEV'], label='Test_ULEV')
plt.plot(compare_Y['Predict_ULEV'], label='Predict_ULEV')
plt.legend()
